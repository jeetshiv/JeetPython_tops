# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d=pd.read_excel('D:/interview questions/project/HR Data.xlsx')
d
# Out:
#      Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0          Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1           No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2          Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3           No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4           No      Travel_Rarely     25 - 34  Current Employees        R&D
# ...        ...                ...         ...                ...        ...
# 1465       Yes         Non-Travel     25 - 34       Ex-Employees        R&D
# 1466       Yes  Travel_Frequently     25 - 34       Ex-Employees        R&D
# 1467       Yes  Travel_Frequently     35 - 44       Ex-Employees      Sales
# 1468       Yes      Travel_Rarely    Under 25       Ex-Employees        R&D
# 1469       Yes      Travel_Rarely    Under 25       Ex-Employees      Sales
#
# ...

# %%
d.isnull()
# Out:
#       Attrition  Business Travel  CF_age band  CF_attrition label  Department  \
# 0         False            False        False               False       False
# 1         False            False        False               False       False
# 2         False            False        False               False       False
# 3         False            False        False               False       False
# 4         False            False        False               False       False
# ...         ...              ...          ...                 ...         ...
# 1465      False            False        False               False       False
# 1466      False            False        False               False       False
# 1467      False            False        False               False       False
# 1468      False            False        False               False       False
# 1469      False            False        False               False       False
#
# ...

# %%
d.mean()
# Out:
# C:\Users\Sony Vaio\AppData\Local\Temp\ipykernel_8536\1214089992.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   d.mean()
# Employee Number                1024.865306
# Training Times Last Year          2.799320
# Age                              36.923810
# CF_current Employee               0.838776
# Daily Rate                      802.485714
# Distance From Home                9.192517
# Employee Count                    1.000000
# Environment Satisfaction          2.721769
# Hourly Rate                      65.891156
# Job Involvement                   2.729932
# Job Level                         2.063946
# Job Satisfaction                  2.728571
# Monthly Income                 6502.931293
# Monthly Rate                  14313.103401
# ...

# %%
x=d['Attrition']
y=d['Department']
plt.hist(x,bins=200)
plt.show()

# %%
x=d['Attrition']
y=d['Department']
plt.hist(y,bins=20)
plt.show()

# %%
x=d['Attrition']
for i in range(len(x)):
    if x[i]=='Yes':
        x[i]=1
    elif x[i]=='No':
        x[i]=0
# Out:
# C:\Users\Sony Vaio\AppData\Local\Temp\ipykernel_1088\1372873231.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[i]=1
# C:\Users\Sony Vaio\AppData\Local\Temp\ipykernel_1088\1372873231.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[i]=0

# %%
d
# Out:
#      Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0            1      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1            0  Travel_Frequently     45 - 54  Current Employees        R&D
# 2            1      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3            0  Travel_Frequently     25 - 34  Current Employees        R&D
# 4            0      Travel_Rarely     25 - 34  Current Employees        R&D
# ...        ...                ...         ...                ...        ...
# 1465         1         Non-Travel     25 - 34       Ex-Employees        R&D
# 1466         1  Travel_Frequently     25 - 34       Ex-Employees        R&D
# 1467         1  Travel_Frequently     35 - 44       Ex-Employees      Sales
# 1468         1      Travel_Rarely    Under 25       Ex-Employees        R&D
# 1469         1      Travel_Rarely    Under 25       Ex-Employees      Sales
#
# ...

# %%
d.head()
# Out:
#   Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0         1      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1         0  Travel_Frequently     45 - 54  Current Employees        R&D
# 2         1      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3         0  Travel_Frequently     25 - 34  Current Employees        R&D
# 4         0      Travel_Rarely     25 - 34  Current Employees        R&D
#
#   Education Field   emp no  Employee Number  Gender               Job Role  \
# 0   Life Sciences  STAFF-1                1  Female        Sales Executive
# 1   Life Sciences  STAFF-2                2    Male     Research Scientist
# 2           Other  STAFF-4                4    Male  Laboratory Technician
# 3   Life Sciences  STAFF-5                5  Female     Research Scientist
# 4         Medical  STAFF-7                7    Male  Laboratory Technician
#
#    ... Performance Rating Relationship Satisfaction Standard Hours  \
# ...

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
plt.figure(figsize=(20,8))
sns.scatterplot(data=d,x='Job Role',y='Department',size=900)
# Out:
# <Axes: xlabel='Job Role', ylabel='Department'>

# %%
sns.lineplot(data = d, x='Department', y='Performance Rating')
# Out:
# <Axes: xlabel='Department', ylabel='Performance Rating'>

# %%
plt.figure(figsize=(15,8))
sns.histplot(data=d,x='Total Working Years')
# Out:
# <Axes: xlabel='Total Working Years', ylabel='Count'>

# %%
plt.figure(figsize=(15,8))
sns.histplot(data=d,x='Total Working Years',bins=45)
# Out:
# <Axes: xlabel='Total Working Years', ylabel='Count'>

# %%
plt.figure(figsize=(15,8))
sns.kdeplot(data=d,x='Total Working Years')
# Out:
# <Axes: xlabel='Total Working Years', ylabel='Density'>

# %%
plt.figure(figsize=(15,8))
sns.kdeplot(data=d,y='Total Working Years')
# Out:
# <Axes: xlabel='Density', ylabel='Total Working Years'>

# %%
plt.figure(figsize=(20,5))
sns.boxplot(x='Age',y='Performance Rating',data=d)
# Out:
# <Axes: xlabel='Age', ylabel='Performance Rating'>

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=(15,8))
sns.pointplot(data=d,x='Department',y='Attrition',hue='Relationship Satisfaction',dodge=True)
# Out:
# <Axes: xlabel='Department', ylabel='Attrition'>

# %%
plt.figure(figsize=(15,8))
sns.stripplot(data=d,x='Department',y='Job Role',hue='Total Working Years')
# Out:
# <Axes: xlabel='Department', ylabel='Job Role'>
